# %% [markdown]
# # Import dependencies

# %%
import numpy as np
import copy
import matplotlib.pyplot as plt
import sklearn
import sklearn.datasets
import sklearn.linear_model

# %% [markdown]
#  # Define dataset

# %%
def load_planar_dataset():
    np.random.seed(1)
    m = 400 # number of examples
    N = int(m/2) # number of points per class
    D = 2 # dimensionality
    X = np.zeros((m,D)) # data matrix where each row is a single example
    Y = np.zeros((m,1), dtype='uint8') # labels vector (0 for red, 1 for blue)
    a = 4 # maximum ray of the flower

    for j in range(2):
        ix = range(N*j,N*(j+1))
        t = np.linspace(j*3.12,(j+1)*3.12,N) + np.random.randn(N)*0.2 # theta
        r = a*np.sin(4*t) + np.random.randn(N)*0.2 # radius
        X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
        Y[ix] = j
        
    X = X.T
    Y = Y.T

    return X, Y

# %% [markdown]
# # Load dataset

# %%
X, Y = load_planar_dataset()

# %% [markdown]
# # Visualize the data

# %%
plt.scatter(X[0, :], X[1, :], c=Y, s=10, cmap=plt.cm.Spectral);

# %%
print ('The shape of X is: ', X.shape)
print ('The shape of Y is: ', Y.shape)
print ('I have m = %d training examples!', (X.shape[1]))
# Out:
# The shape of X is:  (2, 400)
# The shape of Y is:  (1, 400)
# I have m = %d training examples! 400

# %% [markdown]
# # Define the hidden layer size

# %%
hidden_layer_nodes = 4

def layer_sizes(X, Y):
    n_x = X.shape[0]
    n_h = hidden_layer_nodes
    n_y = Y.shape[0]

    return (n_x, n_h, n_y)

# %% [markdown]
# # Define activation function

# %%
def sigmoid(x):
    
    s = 1/(1+np.exp(-x))
    return s

# %% [markdown]
# # Define function for parameter (weight and bias) initialization

# %%
def initialize_parameters(n_x, n_h, n_y):
    
    np.random.seed(2)

    W1 = np.random.randn(n_h,n_x) * 0.01
    b1 = np.zeros((n_h,1))
    
    W2 = np.random.randn(n_y,n_h) * 0.01
    b2 = np.zeros((n_y,1))

    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %% [markdown]
# # Forward propagation

# %%
def forward_propagation(X, parameters):
    
    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]
    
    Z1 = np.dot(W1,X) + b1
    A1 = np.tanh(Z1)
    
    Z2 = np.dot(W2,A1) + b2
    A2 = sigmoid(Z2)
    
    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %% [markdown]
# # Compute cost

# %%
def compute_cost(A2, Y):

    m = Y.shape[1] # number of examples

    logprobs = np.multiply(Y, np.log(A2)) + np.multiply((1 - Y), np.log(1 - A2))
    cost = - np.multiply(1/m, np.sum(logprobs))  
    cost = float(np.squeeze(cost))                             
    
    return cost

# %% [markdown]
# # Backward propagation

# %%
def backward_propagation(parameters, cache, X, Y):

    m = X.shape[1]
    W1 = parameters["W1"]
    W2 = parameters["W2"]
    
    A1 = cache["A1"]
    A2 = cache["A2"]

    dZ2 = A2 - Y
    dW2 = np.multiply(1/m, np.dot(dZ2, np.transpose(A1)))
    db2 = np.multiply(1/m, np.sum(dZ2, axis = 1, keepdims = True))
    dZ1 = np.multiply(np.dot(np.transpose(W2), dZ2), (1 - np.power(A1, 2)))
    dW1 = np.multiply(1/m, np.dot(dZ1, np.transpose(X)))
    db1 = np.multiply(1/m, np.sum(dZ1, axis = 1, keepdims = True))
    
    grads = {"dW1": dW1,
             "db1": db1,
             "dW2": dW2,
             "db2": db2}
    
    return grads

# %% [markdown]
# # Update parameters

# %%
def update_parameters(parameters, grads, learning_rate = 1.2):
    
    W1 = copy.deepcopy(parameters["W1"]) 
    b1 = copy.deepcopy(parameters["b1"]) 
    W2 = copy.deepcopy(parameters["W2"]) 
    b2 = copy.deepcopy(parameters["b2"]) 
    
    dW1 = copy.deepcopy(grads["dW1"]) 
    db1 = copy.deepcopy(grads["db1"])
    dW2 = copy.deepcopy(grads["dW2"])
    db2 = copy.deepcopy(grads["db2"])
    
    W1 = W1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    W2 = W2 - learning_rate * dW2
    b2 = b2 - learning_rate * db2

    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %% [markdown]
# # Full NN model

# %%
def nn_model(X, Y, n_h, num_iterations = 10000, print_cost=False):
    
    np.random.seed(3)
    n_x = layer_sizes(X, Y)[0]
    n_y = layer_sizes(X, Y)[2]
    
    parameters = initialize_parameters(n_x, n_h, n_y)
   
    for i in range(0, num_iterations):
        
        A2, cache = forward_propagation(X, parameters)
        cost = compute_cost(A2, Y)
        grads = backward_propagation(parameters, cache, X, Y)
        parameters = update_parameters(parameters, grads, learning_rate = 1.2)
        
        # Print the cost every 1000 iterations
        if print_cost and i % 1000 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))

    return parameters

# %% [markdown]
# # Test on our dataset

# %%
parameters = nn_model(X, Y, n_h = 4, num_iterations = 100000, print_cost=True)
# Out:
# Cost after iteration 0: 0.693048
# Cost after iteration 1000: 0.288083
# Cost after iteration 2000: 0.254385
# Cost after iteration 3000: 0.233864
# Cost after iteration 4000: 0.226792
# Cost after iteration 5000: 0.222644
# Cost after iteration 6000: 0.219731
# Cost after iteration 7000: 0.217504
# Cost after iteration 8000: 0.219404
# Cost after iteration 9000: 0.218544
# Cost after iteration 10000: 0.217816
# Cost after iteration 11000: 0.217188
# Cost after iteration 12000: 0.216644
# Cost after iteration 13000: 0.216169
# Cost after iteration 14000: 0.215749
# Cost after iteration 15000: 0.215374
# Cost after iteration 16000: 0.215035
# Cost after iteration 17000: 0.214728
# Cost after iteration 18000: 0.214447
# Cost after iteration 19000: 0.214188
# Cost after iteration 20000: 0.213949
# Cost after iteration 21000: 0.213726
# Cost after iteration 22000: 0.213519
# Cost after iteration 23000: 0.213325
# Cost after iteration 24000: 0.213142
# Cost after iteration 25000: 0.212970
# Cost after iteration 26000: 0.212808
# Cost after iteration 27000: 0.212654
# Cost after iteration 28000: 0.212508
# Cost after iteration 29000: 0.212369
# Cost after iteration 30000: 0.212236
# Cost after iteration 31000: 0.212109
# Cost after iteration 32000: 0.211988
# Cost after iteration 33000: 0.211872
# Cost after iteration 34000: 0.211760
# Cost after iteration 35000: 0.211653
# Cost after iteration 36000: 0.211549
# Cost after iteration 37000: 0.211449
# Cost after iteration 38000: 0.211353
# Cost after iteration 39000: 0.211260
# Cost after iteration 40000: 0.211170
# Cost after iteration 41000: 0.211082
# Cost after iteration 42000: 0.210997
# Cost after iteration 43000: 0.210915
# Cost after iteration 44000: 0.210835
# Cost after iteration 45000: 0.210757
# Cost after iteration 46000: 0.210682
# Cost after iteration 47000: 0.210608
# Cost after iteration 48000: 0.210536
# Cost after iteration 49000: 0.210466
# Cost after iteration 50000: 0.210397
# Cost after iteration 51000: 0.210330
# Cost after iteration 52000: 0.210265
# Cost after iteration 53000: 0.210201
# Cost after iteration 54000: 0.210138
# Cost after iteration 55000: 0.210076
# Cost after iteration 56000: 0.210016
# Cost after iteration 57000: 0.209957
# Cost after iteration 58000: 0.209899
# Cost after iteration 59000: 0.209842
# Cost after iteration 60000: 0.209786
# Cost after iteration 61000: 0.209731
# Cost after iteration 62000: 0.209677
# Cost after iteration 63000: 0.209624
# Cost after iteration 64000: 0.209572
# Cost after iteration 65000: 0.209521
# Cost after iteration 66000: 0.209470
# Cost after iteration 67000: 0.209420
# Cost after iteration 68000: 0.209371
# Cost after iteration 69000: 0.209322
# Cost after iteration 70000: 0.209275
# Cost after iteration 71000: 0.209227
# Cost after iteration 72000: 0.209181
# Cost after iteration 73000: 0.209135
# Cost after iteration 74000: 0.209090
# Cost after iteration 75000: 0.209045
# Cost after iteration 76000: 0.209001
# Cost after iteration 77000: 0.208957
# Cost after iteration 78000: 0.208914
# Cost after iteration 79000: 0.208871
# Cost after iteration 80000: 0.208829
# Cost after iteration 81000: 0.208787
# Cost after iteration 82000: 0.208746
# Cost after iteration 83000: 0.208705
# Cost after iteration 84000: 0.208665
# Cost after iteration 85000: 0.208625
# Cost after iteration 86000: 0.208585
# Cost after iteration 87000: 0.208546
# Cost after iteration 88000: 0.208507
# Cost after iteration 89000: 0.208469
# Cost after iteration 90000: 0.208430
# Cost after iteration 91000: 0.208393
# Cost after iteration 92000: 0.208355
# Cost after iteration 93000: 0.208318
# Cost after iteration 94000: 0.208281
# Cost after iteration 95000: 0.208245
# Cost after iteration 96000: 0.208209
# Cost after iteration 97000: 0.208173
# Cost after iteration 98000: 0.208137
# Cost after iteration 99000: 0.208102

# %% [markdown]
# # Predict function

# %%
def predict(parameters, X):

    A2, cache = forward_propagation(X, parameters)
    predictions = (A2 > 0.5)

    return predictions

# %% [markdown]
# # Plot decision boundary

# %%
def plot_decision_boundary(model, X, y):
    # Set min and max values and give it some padding
    x_min, x_max = X[0, :].min() - 1, X[0, :].max() + 1
    y_min, y_max = X[1, :].min() - 1, X[1, :].max() + 1
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole grid
    Z = model(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.ylabel('x2')
    plt.xlabel('x1')
    plt.scatter(X[0, :], X[1, :], c=y, cmap=plt.cm.Spectral)

# %%
plot_decision_boundary(lambda x: predict(parameters, x.T), X, Y)
plt.title("Decision Boundary for hidden layer size " + str(4))
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 4')

# %% [markdown]
# # Tuning hidden layer size

# %%
plt.figure(figsize=(16, 32))
hidden_layer_sizes = [1, 2, 3, 4, 5, 20, 50]
for i, n_h in enumerate(hidden_layer_sizes):
    plt.subplot(5, 2, i+1)
    plt.title('Hidden Layer of size %d' % n_h)
    parameters = nn_model(X, Y, n_h, num_iterations = 5000)
    plot_decision_boundary(lambda x: predict(parameters, x.T), X, Y)
    predictions = predict(parameters, X)
    accuracy = float((np.dot(Y,predictions.T) + np.dot(1 - Y, 1 - predictions.T)) / float(Y.size)*100)
    print ("Accuracy for {} hidden units: {} %".format(n_h, accuracy))
# Out:
# Accuracy for 1 hidden units: 67.5 %
# Accuracy for 2 hidden units: 67.25 %
# Accuracy for 3 hidden units: 90.75 %
# Accuracy for 4 hidden units: 90.5 %
# Accuracy for 5 hidden units: 91.25 %
# Accuracy for 20 hidden units: 90.5 %
# Accuracy for 50 hidden units: 90.25 %

# %% [markdown]
# ## Assignment:
#
# Run the notebook and test if everything runs fine.
#
# Test previous cell with different hidden layer size.
#
# Write your conclusion and observations.
