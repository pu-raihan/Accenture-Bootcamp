# %% [markdown]
# # Transformers, what can they do?

# %%
from transformers import pipeline
import warnings
warnings.filterwarnings('ignore')

classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9598049521446228}]

# %%
classifier(
    ["I've been waiting for a HuggingFace course my whole life.", "I hate this so much!"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598049521446228},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %%
classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445991277694702, 0.1119740828871727, 0.04342679679393768]}

# %%
# Look for Assignment Nr.1
generator = pipeline("text-generation", model="distilgpt2")

outputs = generator(
    "In this course, we will teach you how to",
    max_length=15,
    num_return_sequences=2,
)
# Out:
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=15) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
for i, output in enumerate(outputs):
    text = output["generated_text"]
    words = text.split()
    
    trimmed_text = ' '.join(words[:15])
    print(f"Sentence {i+1}: {trimmed_text}")
# Out:
# Sentence 1: In this course, we will teach you how to make an effective, well-informed decision to
# Sentence 2: In this course, we will teach you how to get a decent job in the

# %%
# Look for Assignment Nr.2

from transformers import pipeline

generator = pipeline("text-generation", model="asi/gpt-fr-cased-small")

outputs_2 = generator(
    "Dans ce cours, nous allons vous apprendre comment",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
for i, output in enumerate(outputs_2):
    text = output["generated_text"]
    
    print(f"\nSentence {i+1}: {text}")
# Out:
# Sentence 1: Dans ce cours, nous allons vous apprendre comment mettre le corps dans l'eau et la faire bouillir. " Nous avons pensé que les enfants qui doivent passer dans la douche devaient être nus. Nous avons fait une sorte de "baiser" de la douche. Le "baiser" de la douche est un peu comme "Baiser la grenouille". Il a été écrit sur un tableau d'affichage avec l'image de la grenouille. "Baiser la grenouille" est une expression très populaire, et nous savons que c'est une expression très intéressante. Les enfants ont été les premiers à utiliser cette expression. Le mot grenouille signifie "se faire "baiser" " (baiser) " (baiser) " (homme). Une grenouille est une personne qui fait partie d'un groupe de personnes qui veulent être "baiser" une grenouille. Nous disons "baiser" le "baiser " (homme) et "baiser " (homme) pour montrer qu'ils vont être "baiser " (homme). Nous parlons de la grenouille dans toute la ville. "Baiser la grenouille" est une expression très courante. Nous sommes heureux de dire que, de nos jours, nous avons eu une "baiser " (baiser) la grenouille. Nous avons entendu dire qu'une grenouille est
#
# Sentence 2: Dans ce cours, nous allons vous apprendre comment éviter que le fils de votre femme, pour être plus sûr, ne se rende compte de tout ce qui lui est arrivé. Les enfants ne sont pas faits pour être élevés par les parents. La mère travaille trop pour que son fils ne soit pas fait comme elle l'entend. C'est pour cela que vous lui conseillez d'aller jusqu'au bout. Qu'est-ce que ça signifie pour vous? Je vais dire ce que signifie pour vous. Je ne vous demande pas d'en faire autant pour vous. Ce qui s'est passé est grave. On vous a dit qu'une femme allait vous épouser. De toute façon, vous avez besoin de votre fille pour votre fille et pour vous-même. C'est vrai que vous ne vous êtes pas encore mariés. Mais il y a une grande différence. C'est à cause de votre fille. Elle est amoureuse de vous. Vous avez une petite fille. Vous ne pouvez pas la quitter. Je ne veux pas la quitter. Nous ne pouvons vraiment pas la quitter. Les enfants d'aujourd'hui ne sont pas faits pour être élevés par les parents. Nous ne pouvons pas nous marier à nouveau. Nous ne pouvons pas être parents et ne devons pas être mariés à nouveau. Vous ne devez

# %%
# Look for Assignment Nr.3

unmasker = pipeline("fill-mask", model="bert-base-cased")

outputs_3 = unmasker("This course will teach you all about [MASK] models.", top_k=2)
outputs_from_2 = unmasker("Dans ce cours, nous allons vous apprendre comment [MASK]", top_k=2)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu

# %%
for i, output in enumerate(outputs_3):
    print(f"Prediction {i+1}:")
    print(f"  Token: {output['token_str']}")
    print(f"  Score: {output['score']}")
    print(f"  Sentence: {output['sequence']}")
    print()

print("from assignment 2")
for i, output in enumerate(outputs_from_2):
    print(f"Prediction {i+1}:")
    print(f"  Token: {output['token_str']}")
    print(f"  Score: {output['score']}")
    print(f"  Sentence: {output['sequence']}")
    print()
# Out:
# Prediction 1:
#   Token: role
#   Score: 0.2596316635608673
#   Sentence: This course will teach you all about role models.
#
# Prediction 2:
#   Token: the
#   Score: 0.09427245706319809
#   Sentence: This course will teach you all about the models.
#
# from assignment 2
# Prediction 1:
#   Token: .
#   Score: 0.8187247514724731
#   Sentence: Dans ce cours, nous allons vous apprendre comment.
#
# Prediction 2:
#   Token: !
#   Score: 0.10516960173845291
#   Sentence: Dans ce cours, nous allons vous apprendre comment!

# %%
# Named entity recognition (NER) is a task where the model has to find which parts of the input text 
# correspond to entities such as persons, locations, or organizations.

# Look for Assignment Nr.4
pos_tagger = pipeline(
    "token-classification",
    model="vblagoje/bert-english-uncased-finetuned-pos",
    aggregation_strategy="simple"
)

sentence = "My name is Sylvain and I work at Hugging Face in Brooklyn."

results = pos_tagger(sentence)

for token in results:
    print(f"{token['word']:12} -> {token['entity_group']}")
# Out:
# Some weights of the model checkpoint at vblagoje/bert-english-uncased-finetuned-pos were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# my           -> PRON
# name         -> NOUN
# is           -> AUX
# sylvain      -> PROPN
# and          -> CCONJ
# i            -> PRON
# work         -> VERB
# at           -> ADP
# hugging face -> PROPN
# in           -> ADP
# brooklyn     -> PROPN
# .            -> PUNCT

# %%
results_from_3 = pos_tagger("This course will teach you all about role models")
for token in results_from_3:
    print(f"{token['word']:12} -> {token['entity_group']}")
# Out:
# this         -> DET
# course       -> NOUN
# will         -> AUX
# teach        -> VERB
# you          -> PRON
# all          -> DET
# about        -> ADP
# role models  -> NOUN

# %%
question_answerer = pipeline("question-answering")
question_answerer(
    question="Where do I work?",
    context="My name is Sylvain and I work at Hugging Face in Brooklyn",
)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# {'score': 0.6949770450592041, 'start': 33, 'end': 45, 'answer': 'Hugging Face'}

# %%
summarizer = pipeline("summarization")
summarizer(
    """
    America has changed dramatically during recent years. Not only has the number of
    graduates in traditional engineering disciplines such as mechanical, civil,
    electrical, chemical, and aeronautical engineering declined, but in most of
    the premier American universities engineering curricula now concentrate on
    and encourage largely the study of engineering science. As a result, there
    are declining offerings in engineering subjects dealing with infrastructure,
    the environment, and related issues, and greater concentration on high
    technology subjects, largely supporting increasingly complex scientific
    developments. While the latter is important, it should not be at the expense
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other
    industrial countries in Europe and Asia, continue to encourage and advance
    the teaching of engineering. Both China and India, respectively, graduate
    six and eight times as many traditional engineers as does the United States.
    Other industrial countries at minimum maintain their output, while America
    suffers an increasingly serious decline in the number of engineering graduates
    and a lack of well-educated engineers.
"""
)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'summary_text': ' The number of engineering graduates in the United States has declined in recent years . China and India graduate six and eight times as many traditional engineers as the U.S. does . Rapidly developing economies such as China continue to encourage and advance the teaching of engineering . There are declining offerings in engineering subjects dealing with infrastructure, infrastructure, the environment, and related issues .'}]

# %%
# Look for Assignment Nr.5
translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
translator("Ce cours est produit par Hugging Face.")
# Out:
# Device set to use cpu
# [{'translation_text': 'This course is produced by Hugging Face.'}]

# %%
for i, output in enumerate(outputs_2):
    text = output["generated_text"]
    print(translator(text))
# Out:
# [{'translation_text': 'In this course, we\'re going to teach you how to put the body in the water and boil it. "We thought that the children who have to go through the shower had to be naked. We made a kind of "bathing" of the shower. The "bathing" of the shower is a bit like "bashing the frog". It was written on a scoreboard with the image of the frog. "bashing the frog" is a very popular expression, and we know that it\'s a very interesting expression. Children were the first to use this expression. The word frog means to get "bathed" (bashing)" (bashing) " (man). A frog is a person who is part of a group of people who want to be "bath" a frog. We say "bath" it "man" and "bath" (man) to show that they are going to be "bathed" (man). We talk about the frog throughout the city. "bashing the frog" is a very common expression. We\'re happy to say that, from our days, "we\'ve heard a frog" (we\'ve had a frog).'}]

# %% [markdown]
# ## Assignment
#
# 1. Use the num_return_sequences and max_length arguments to generate two sentences of 15 words each.
# 2. Use the filters to find a text generation model for another language. Feel free to play with the widget and use it in a pipeline!
# 3. Search for the bert-base-cased model on the Hub and identify its mask word in the Inference API widget. What does this model predict for the sentence in our pipeline example above?
# 4. Search the Model Hub for a model able to do part-of-speech tagging (usually abbreviated as POS) in English. What does this model predict for the sentence in the example above?
# 5. Search for translation models in other languages and try to translate the previous sentence into a few different languages.

# %% [markdown]
# ## License
# Source: https://huggingface.co/learn/llm-course/chapter1/3
